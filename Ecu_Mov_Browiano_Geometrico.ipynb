# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/SIMULACION-II/blob/main/Ecu_Mov_Browiano_Geometrico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# S I M U L A C I Ó N --  M O N T E C A R L O

# %%
import random as rd
import matplotlib.pyplot as plt

# %%
def caminante(N, p):
    p = p
    N = N
    Cont = 0
    L = [Cont]
    for i in range(N):
     t = rd.uniform(0,1)
     if t < p:
        Cont += 1
     else:
        Cont -= 1
     L.append(Cont)
    plt.plot(L)

# %%
for i in range(100):
 caminante(400,0.6)

# %%
for i in range(100):
 caminante(400,0.5)

# %%
for i in range(100):
 caminante(400,0.3)

# %% [markdown]
# NOTA: Cuando la probabiliodad es menor a 0.5 , la tendencia va hacia abajo, y cuando la probabilidad es mayor a 0.5, la tendencia va hacia arriba.
